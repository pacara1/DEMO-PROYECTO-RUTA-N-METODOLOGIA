# %%
##
## Preparación
##
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import openpyxl
import pandas as pd
import numpy as np
import time, datetime
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
excel_document = openpyxl.load_workbook('files/MUERTOS.xlsx')
sheets=excel_document.get_sheet_names()
list(pd.read_excel('files/MUERTOS.xlsx',sheets[1]).columns[:])
df5=pd.DataFrame(columns=list(pd.read_excel('files/MUERTOS.xlsx',sheets[1]).columns[:]))
for x in range(len(excel_document.get_sheet_names())):
    df5=pd.concat([df5, pd.read_excel('files/MUERTOS.xlsx',sheets[x], parse_dates=['Fecha Ocurrencia'], index=True)])
df5.index=list(range(len(df5['Fecha Ocurrencia'])))
df5
data=df5.groupby('Fecha Ocurrencia')
df=pd.DataFrame({'Muertes': list(data['Fecha Ocurrencia'].value_counts())},index=list(data.groups.keys()))
df1=pd.DataFrame({'Muertes': list(data.groups.keys())})
df
# Out:
# C:\Users\Paolo Camacho\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated function get_sheet_names (Use wb.sheetnames).
#   if __name__ == '__main__':
# C:\Users\Paolo Camacho\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: DeprecationWarning: Call to deprecated function get_sheet_names (Use wb.sheetnames).
#   if sys.path[0] == '':
# C:\Users\Paolo Camacho\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   del sys.path[0]
#             Muertes
# 2008-01-01        1
# 2008-01-02        2
# 2008-01-04        1
# 2008-01-08        1
# 2008-01-09        1
# 2008-01-11        2
# 2008-01-13        3
# 2008-01-16        1
# 2008-01-17        2
# 2008-01-18        1
# ...

# %%
T=df.asfreq(freq='D', fill_value=0)

# %%
T
# Out:
#             Muertes
# 2008-01-01        1
# 2008-01-02        2
# 2008-01-03        0
# 2008-01-04        1
# 2008-01-05        0
# 2008-01-06        0
# 2008-01-07        0
# 2008-01-08        1
# 2008-01-09        1
# 2008-01-10        0
# 2008-01-11        2
# 2008-01-12        0
# 2008-01-13        3
# 2008-01-14        0
# 2008-01-15        0
# 2008-01-16        1
# 2008-01-17        2
# 2008-01-18        1
# 2008-01-19        0
# 2008-01-20        1
# 2008-01-21        0
# 2008-01-22        0
# 2008-01-23        1
# 2008-01-24        1
# 2008-01-25        0
# 2008-01-26        2
# 2008-01-27        1
# 2008-01-28        0
# 2008-01-29        0
# 2008-01-30        2
# ...             ...
# 2019-07-20        2
# 2019-07-21        0
# 2019-07-22        2
# 2019-07-23        0
# 2019-07-24        0
# 2019-07-25        0
# 2019-07-26        3
# 2019-07-27        3
# 2019-07-28        1
# 2019-07-29        0
# 2019-07-30        2
# 2019-07-31        0
# 2019-08-01        1
# ...

# %%
T.astype(float)
# Out:
#             Muertes
# 2008-01-01      1.0
# 2008-01-02      2.0
# 2008-01-03      0.0
# 2008-01-04      1.0
# 2008-01-05      0.0
# 2008-01-06      0.0
# 2008-01-07      0.0
# 2008-01-08      1.0
# 2008-01-09      1.0
# 2008-01-10      0.0
# 2008-01-11      2.0
# 2008-01-12      0.0
# 2008-01-13      3.0
# 2008-01-14      0.0
# 2008-01-15      0.0
# 2008-01-16      1.0
# 2008-01-17      2.0
# 2008-01-18      1.0
# 2008-01-19      0.0
# 2008-01-20      1.0
# 2008-01-21      0.0
# 2008-01-22      0.0
# 2008-01-23      1.0
# 2008-01-24      1.0
# 2008-01-25      0.0
# 2008-01-26      2.0
# 2008-01-27      1.0
# 2008-01-28      0.0
# 2008-01-29      0.0
# 2008-01-30      2.0
# ...             ...
# 2019-07-20      2.0
# 2019-07-21      0.0
# 2019-07-22      2.0
# 2019-07-23      0.0
# 2019-07-24      0.0
# 2019-07-25      0.0
# 2019-07-26      3.0
# 2019-07-27      3.0
# 2019-07-28      1.0
# 2019-07-29      0.0
# 2019-07-30      2.0
# 2019-07-31      0.0
# 2019-08-01      1.0
# ...

# %%
T.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
X=T.index.to_numpy( ).astype(float)
X
# Out:
# array([1.1991456e+18, 1.1992320e+18, 1.1993184e+18, ..., 1.5659136e+18,
#        1.5660000e+18, 1.5660864e+18])

# %%
#X=DatetimeArray(np.array(list(T.index[:])))
d=np.array(list(T['Muertes'][:]))
plt.scatter(df.index[:], df['Muertes'][:]);

# %%
X =X.reshape(-1,1)
#d =d.reshape(-1,1)

# %%
print(X)
# Out:
# [[1.1991456e+18]
#  [1.1992320e+18]
#  [1.1993184e+18]
#  ...
#  [1.5659136e+18]
#  [1.5660000e+18]
#  [1.5660864e+18]]

# %%
np.array(d)
# Out:
# array([1, 2, 0, ..., 1, 1, 1])

# %%
print(d)
# Out:
# [1 2 1 ... 1 1 1]

# %%
##
## Se usa la función LinearRegresion() para
## estimar el modelo de regresión lineal.
##
from sklearn.linear_model import LinearRegression

## Crea el modelo

linearRegression = LinearRegression(
    fit_intercept=True,               # ?intercepto (w0)
    normalize=False,                  # solo para fit_intercept == False
    copy_X=True                       # copia X o lo sobreescribe
)

## Calibra el modelo
linearRegression.fit(X, d)

## Imprime los coeficientes:
print('Coeficientes: ', linearRegression.coef_)

## Imprime el intercepto:
print('Intercepto: ', linearRegression.intercept_)
# Out:
# Coeficientes:  [-6.08409503e-19]
# Intercepto:  1.618974490536204

# %%
#PRONOSTICO

# %%
df6 = pd.DataFrame(X, columns = ['x'])
df6['d'] = d
df6['y_pred'] = linearRegression.predict(X)
df6.y_pred.head()
# Out:
# 0    0.889403
# 1    0.889350
# 2    0.889298
# 3    0.889245
# 4    0.889193
# Name: y_pred, dtype: float64

# %%
##
## Gráfico del pronóstico
##
df6.plot.scatter('x', 'd', color='black');
plt.plot(df6[['x']].values, df6.y_pred, color='red');
